# %% [markdown]
# # Cloning

# %% [markdown]
# *1epochs : 10 min, 0.072 h = 4.32 min*
#
# *5 epochs train: 0.348 h = 20.88 min*
#
# *10 epochs train: 0.691 h = 41.46 min*
#
# *15 epochs train: 1.040 h = - min*
#
# *20 epochs train: -- h = -- min*
#
# *25 epochs train: -- h = -- min*

# %%
#!git clone https://github.com/Ha-lm31/TrackingCount.git
# !git clone https://github.com/Ha-lm31/PFE-Module1.git
# Out:
# Cloning into 'PFE-Module1'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 133 (delta 0), reused 6 (delta 0), pack-reused 122 (from 2)
# Receiving objects: 100% (133/133), 60.29 MiB | 45.20 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %% [markdown]
# # Installation of torch

# %%
# 1. Supprimer les versions actuelles de torch
# !pip uninstall -y torch torchvision torchaudio

# 2. Installer une version stable (compatible YOLOv8, sans weights_only bug)
# !pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu118

'''# 3. Redémarrer automatiquement le kernel
import os
os._exit(00)'''
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 571.8 kB/s eta 0:00:000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 57.6 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 49.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 19.0 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
# ...

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: accelerate, easyocr, fastai, kornia, peft, pytorch-ignite, pytorch-lightning, sentence-transformers, stable-baselines3, timm, torchaudio, torchdata, torchmetrics, torchvision

# %% [markdown]
# # Path

# %%
from IPython.display import Image
import os

BASE_PATH = '/kaggle/working/PFE-Module1'
home1 = os.path.join(BASE_PATH, 'YOLOv8-DeepSORT-Object-Tracking')
home2 = os.path.join(home1, 'ultralytics/yolo/v8/detect')

print("Exécution terminer")
# Out:
# Exécution terminer

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# %cd {home1}
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 62.0 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 98.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 37.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.1/392.1 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %cd {home2}
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !pip show roboflow
# Out:
# Name: roboflow
# Version: 1.1.65
# Summary: Official Python package for working with the Roboflow API
# Home-page: https://github.com/roboflow-ai/roboflow-python
# Author: Roboflow
# Author-email: support@roboflow.com
# License: UNKNOWN
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: certifi, cycler, filetype, idna, kiwisolver, matplotlib, numpy, opencv-python-headless, Pillow, pillow-heif, python-dateutil, python-dotenv, PyYAML, requests, requests-toolbelt, six, tqdm, urllib3
# Required-by: ultralytics

# %%
#import detection-1
from roboflow import Roboflow

rf = Roboflow(api_key="9j4H4mvkoQZ7DQ8REN58")
project = rf.workspace("drone-dataset-mvh8i").project("detection-bzujh")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to detection-1 in yolov5pytorch:: 100%|██████████| 9374/9374 [00:00<00:00, 10031.49it/s]

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100%|███████████████████████████████████████| 43.1M/43.1M [00:00<00:00, 218MB/s]

# %%
# !unzip 'deep_sort_pytorch.zip'
# Out:
# Archive:  deep_sort_pytorch.zip
#   inflating: deep_sort_pytorch/.gitignore
#    creating: deep_sort_pytorch/configs/
#   inflating: deep_sort_pytorch/configs/deep_sort.yaml
#    creating: deep_sort_pytorch/deep_sort/
#   inflating: deep_sort_pytorch/deep_sort/__init__.py
#    creating: deep_sort_pytorch/deep_sort/__pycache__/
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-38.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-38.pyc
#    creating: deep_sort_pytorch/deep_sort/deep/
#  extracting: deep_sort_pytorch/deep_sort/deep/__init__.py
#    creating: deep_sort_pytorch/deep_sort/deep/__pycache__/
# ...

# %%
# %cd {home2}
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# %cd {dataset.location}
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/detection-1

# %% [markdown]
# # Training

# %%
file_path = os.path.join(home1,'ultralytics/yolo/utils/plotting.py')

with open(file_path, "r") as f:
    lines = f.readlines()

with open(file_path, "w") as f:
    for i, line in enumerate(lines):
        if "self.font.getsize(" in line:
            indent = line[:len(line) - len(line.lstrip())]  # détecter l'indentation
            f.write(f"{indent}bbox = self.font.getbbox(label)\n")
            f.write(f"{indent}w, h = bbox[2] - bbox[0], bbox[3] - bbox[1]  # updated for Pillow>=10.0\n")
        else:
            f.write(line)

print("✅ Correction d’indentation et mise à jour de getsize() effectuée.")
# Out:
# ✅ Correction d’indentation et mise à jour de getsize() effectuée.

# %%
# %cd {home2}

# !export HYDRA_FULL_ERROR=1 && python train.py model=yolov8l.pt data={dataset.location}/data.yaml epochs=1 imgsz=640
#!export HYDRA_FULL_ERROR=1 && python train.py model=yolov8l.pt data={dataset.location}/data.yaml epochs=15 imgsz=640
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# ...
# 100%|███████████████████████████████████████| 83.7M/83.7M [00:00<00:00, 104MB/s]
#
# ...

# %% [markdown]
# # Visualisation

# %%
home3 = os.path.join(BASE_PATH, 'runs/detect/train')
# !ls {home3}
# Out:
# args.yaml					   train_batch0.jpg
# confusion_matrix.png				   train_batch1.jpg
# events.out.tfevents.1748795407.76f686e2cf9e.152.0  train_batch2.jpg
# F1_curve.png					   val_batch0_labels.jpg
# P_curve.png					   val_batch0_pred.jpg
# PR_curve.png					   val_batch1_labels.jpg
# predictions.json				   val_batch1_pred.jpg
# R_curve.png					   val_batch2_labels.jpg
# results.csv					   val_batch2_pred.jpg
# results.png					   weights

# %%
print("results.png")
Image(filename = os.path.join(home3, 'results.png'))
# Out:
# results.png

# %%
#%cd {BASE_PATH}

# %%
'''!rm -rf runs
print("ex")'''

# %%
'''print("F1_curve.png")
Image(filename = os.path.join(home3, 'F1_curve.png'))'''

# %%
'''print("PR_curve.png")
Image(filename = os.path.join(home3, 'PR_curve.png'))'''

# %%
'''print("P_curve.png")
Image(filename = os.path.join(home3, 'P_curve.png'))'''

# %%
'''print("R_curve.png")
Image(filename = os.path.join(home3, 'R_curve.png'))'''

# %%
'''# Afficher les images
print("confusion_matrix.png")
Image(filename = os.path.join(home3, 'confusion_matrix.png'))'''

# %%
'''print("train_batch0.jpg")
Image(filename = os.path.join(home3, 'train_batch0.jpg'))'''

# %%
'''print("train_batch1.jpg")
Image(filename = os.path.join(home3, 'train_batch1.jpg'))'''

# %%
'''print("train_batch2.jpg")
Image(filename = os.path.join(home3, 'train_batch2.jpg'))'''

# %%
'''print("val_batch0_labels.jpg")
Image(filename = os.path.join(home3, 'val_batch0_labels.jpg'))'''

# %%
'''print("val_batch0_pred.jpg")
Image(filename = os.path.join(home3, 'val_batch0_pred.jpg'))'''

# %%
'''print("val_batch1_labels.jpg")
Image(filename = os.path.join(home3, 'val_batch1_labels.jpg'))'''

# %%
'''print("val_batch1_pred.jpg")
Image(filename = os.path.join(home3, 'val_batch1_pred.jpg'))'''

# %%
'''print("val_batch2_labels.jpg")
Image(filename = os.path.join(home3, 'val_batch2_labels.jpg'))'''

# %%
'''print("val_batch2_pred.jpg")
Image(filename = os.path.join(home3, 'val_batch2_pred.jpg'))'''

# %%
# %cd {home2}
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=1VBAZtJ5uJMEsnyya_d0yMP6efBRQ8IX-&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VBAZtJ5uJMEsnyya_d0yMP6efBRQ8IX-&confirm=t
# To: /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/best.pt
# 100%|██████████████████████████████████████| 87.7M/87.7M [00:01<00:00, 86.3MB/s]

# %%
# !pwd
# Out:
# /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %% [markdown]
# # Val

# %%
# !python val.py model='best.pt' data={dataset.location}/data.yaml
# Out:
# 2025-06-01 16:36:11.109801: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748795771.133404     288 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748795771.140729     288 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.3 🚀 Python-3.11.11 torch-2.1.0+cu118 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Fusing layers...
# Model summary: 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultral
# ...

# %%
# !gdown "https://drive.google.com/uc?id=1UUZUS76ylH5RjMSc9s4rITSYDTG5AHt0&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UUZUS76ylH5RjMSc9s4rITSYDTG5AHt0&confirm=t
# To: /kaggle/working/PFE-Module1/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/test4.mp4
# 100%|██████████████████████████████████████| 7.96M/7.96M [00:00<00:00, 31.3MB/s]

# %%
import os
import re

# Répertoire de base du projet (à adapter si nécessaire)
base_dir = "/kaggle/working/TrackingCount/YOLOv8-DeepSORT-Object-Tracking"

# Mappage des alias dépréciés vers les types modernes
replacements = {
    r'\bnp\.float\b': 'float',
    r'\bnp\.int\b': 'int',
    r'\bnp\.bool\b': 'bool',
    r'\bnp\.object\b': 'object',
    r'\bnp\.str\b': 'str',
    r'\bnp\.long\b': 'int',
}

def replace_numpy_aliases(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()

    new_content = content
    for pattern, repl in replacements.items():
        new_content = re.sub(pattern, repl, new_content)

    if new_content != content:
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(new_content)
        print(f"✔️ Modifié : {file_path}")

def scan_and_fix_py_files(base_path):
    for root, dirs, files in os.walk(base_path):
        for filename in files:
            if filename.endswith(".py"):
                full_path = os.path.join(root, filename)
                replace_numpy_aliases(full_path)

# Exécution
print("🔍 Correction des alias NumPy dépréciés en cours...")
scan_and_fix_py_files(base_dir)
print("✅ Terminé.")
# Out:
# 🔍 Correction des alias NumPy dépréciés en cours...
# ✅ Terminé.

# %%
#!python predict.py model='best.pt' source='test4.mp4'

# %% [markdown]
# # Tracking

# %%
# !export HYDRA_FULL_ERROR=1 &&  python tracking.py model='best.pt' source='test4.mp4'
# Out:
# [2025-06-01 16:37:09,072][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2025-06-01 16:37:09.824806: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748795829.848646     366 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748795829.855756     366 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.3 🚀 Python-3.11.11 torch-2.1.0+cu118 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Fusing layers...
# Model summary: 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
# ...

# %%
'''# --- Cellule à insérer dans ton notebook Kaggle pour compter entrées/sorties ---

# Paramètres à ajuster selon ton image/vidéo
line_position = 300  # Position verticale de la ligne (modifie selon la hauteur de ta vidéo)
offset = 10  # Tolérance pour éviter les doubles-comptages

# Historique des centres par ID
track_history = {}
in_count = 0
out_count = 0

def get_center(bbox):
    x1, y1, x2, y2 = bbox
    return int((x1 + x2) / 2), int((y1 + y2) / 2)

# tracked_objects_par_frame = [ [(id, bbox), ...], ... ]  # À adapter à ta variable de résultats !

for frame_idx, tracked_objects in enumerate(tracked_objects_par_frame):
    for obj_id, bbox in tracked_objects:
        center = get_center(bbox)
        if obj_id in track_history:
            prev_center = track_history[obj_id]
            # Vérification du passage de la ligne
            if prev_center[1] < line_position <= center[1]:
                in_count += 1
                print(f"Frame {frame_idx}: Voiture {obj_id} entrée.")
            elif prev_center[1] > line_position >= center[1]:
                out_count += 1
                print(f"Frame {frame_idx}: Voiture {obj_id} sortie.")
        track_history[obj_id] = center

print(f"Nombre total d'entrées : {in_count}")
print(f"Nombre total de sorties : {out_count}")'''

# %%
# !rm {compressed_path}

# %%
save_path = os.path.join(BASE_PATH, 'runs/detect/train3/test4.mp4')
compressed_path = os.path.join(BASE_PATH, 'vedio1.mp4')

# %% [markdown]
# # Demo Vedeo

# %%
from IPython.display import HTML
from base64 import b64encode
import os

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# # Save Folders

# %%
#%cd {BASE_PATH}

# %%
'''import shutil

# Chemin du dossier à compresser
folder_path = 'runs'  # Remplace par le nom de ton dossier

# Nom du fichier zip de sortie
zip_file_name = 'Runs'  # Ne mets pas l'extension .zip ici

# Compression du dossier en .zip
shutil.make_archive(zip_file_name, 'zip', folder_path)

print(f"Le dossier '{folder_path}' a été compressé en '{zip_file_name}.zip'")
'''
